# %% [markdown]
# <a href="https://colab.research.google.com/github/Msbohra/Numpy/blob/main/McKinsey_LifeExpectancy_Insights.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
# !wget "https://drive.google.com/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_" -O mckinsey.csv
# Out:
# --2024-12-18 06:19:09--  https://drive.google.com/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# Resolving drive.google.com (drive.google.com)... 142.251.2.138, 142.251.2.139, 142.251.2.100, ...
# Connecting to drive.google.com (drive.google.com)|142.251.2.138|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_&export=download [following]
# --2024-12-18 06:19:09--  https://drive.usercontent.google.com/download?id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 74.125.137.132, 2607:f8b0:4023:c03::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|74.125.137.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 83785 (82K) [application/octet-stream]
# Saving to: ‘mckinsey.csv’
#
# ...

# %%
df = pd.read_csv("mckinsey.csv")
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df["country"] ## in pandas anything which is string is treated as type object
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
df.info()  #give all information about your data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     1704 non-null   object
#  1   year        1704 non-null   int64
#  2   population  1704 non-null   int64
#  3   continent   1704 non-null   object
#  4   life_exp    1704 non-null   float64
#  5   gdp_cap     1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
df.head() # by default pandas will give 5 rows, but you can fill in the value to fetch as many as you want.
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.tail(2)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
df.head(-2)  #this will remove last 2 rows in the df and return the rest.

# %%
df.country
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %% [markdown]
# ##HOW CAN WE CREATE DATAFRAME FROM SCRATCH

# %%
pd.DataFrame([['Afghanistan',1952, 8425333, 'Asia', 28.801, 779.445314, 45],
              ['Afghanistan',1957, 9240934, 'Asia', 30.332, 820.853030],
              ['Afghanistan',1962, 102267083, 'Asia', 31.997, 853.100710]],
              columns = ['country','year','population','continent','life_exp','gdp_cap', "zdzf"])
# Out:
#        country  year  population continent  life_exp     gdp_cap  zdzf
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314  45.0
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030   NaN
# 2  Afghanistan  1962   102267083      Asia    31.997  853.100710   NaN

# %%
pd.DataFrame({
          'country':['Afghanistan', 'Afghanistan'],
          'year':[1952,1957],
          'population':[842533, 9240934],
          'continent':['Asia', 'Asia'],
          'life_exp':[28.801, 30.332],
          'gdp_cap':[779.445314, 820.853030]
          })
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952      842533      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030

# %%
df.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df.keys #to call columns
# Out:
# <bound method NDFrame.keys of           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]>

# %%
type(df[["country"]])
# Out:
# pandas.core.frame.DataFrame

# %%
type(df["country"]) #everything we learnt in numpy is applicable to series
# Out:
# pandas.core.series.Series

# %%
df[["country","life_exp"]]
# Out:
#           country  life_exp
# 0     Afghanistan    28.801
# 1     Afghanistan    30.332
# 2     Afghanistan    31.997
# 3     Afghanistan    34.020
# 4     Afghanistan    36.088
# ...           ...       ...
# 1699     Zimbabwe    62.351
# 1700     Zimbabwe    60.377
# 1701     Zimbabwe    46.809
# 1702     Zimbabwe    39.989
# 1703     Zimbabwe    43.487
#
# [1704 rows x 2 columns]

# %%
df[["country","life_exp"]].head()
# Out:
#        country  life_exp
# 0  Afghanistan    28.801
# 1  Afghanistan    30.332
# 2  Afghanistan    31.997
# 3  Afghanistan    34.020
# 4  Afghanistan    36.088

# %%
df["country"].unique
# Out:
# <bound method Series.unique of 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object>

# %%
df["country"].nunique() #count distinct
# Out:
# 142

# %%
df["country"].value_counts() # frequency of object
# Out:
# country
# Afghanistan          12
# Pakistan             12
# New Zealand          12
# Nicaragua            12
# Niger                12
#                      ..
# Eritrea              12
# Equatorial Guinea    12
# El Salvador          12
# Egypt                12
# Zimbabwe             12
# Name: count, Length: 142, dtype: int64

# %%
df.rename({"country": "Country","population": "Population"}, axis = 1,  inplace = True)

# %%
df
# Out:
#           Country  year  Population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.rename(columns = {"country": "Country"})
# Out:
#           Country  year  Population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.drop("continent" , axis = 1)
# Out:
#           Country  year  Population  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 3     Afghanistan  1967    11537966    34.020  836.197138
# 4     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df.drop(columns = ["continent","life_exp"] )
# Out:
#           Country  year  Population     gdp_cap  year+2
# 0     Afghanistan  1952     8425333  779.445314    1954
# 1     Afghanistan  1957     9240934  820.853030    1959
# 2     Afghanistan  1962    10267083  853.100710    1964
# 3     Afghanistan  1967    11537966  836.197138    1969
# 4     Afghanistan  1972    13079460  739.981106    1974
# ...           ...   ...         ...         ...     ...
# 1699     Zimbabwe  1987     9216418  706.157306    1989
# 1700     Zimbabwe  1992    10704340  693.420786    1994
# 1701     Zimbabwe  1997    11404948  792.449960    1999
# 1702     Zimbabwe  2002    11926563  672.038623    2004
# 1703     Zimbabwe  2007    12311143  469.709298    2009
#
# [1704 rows x 5 columns]

# %%
## NAN is a float

# %%
df["year+2"] = df["year"]+2

# %%
df.head(2)
# Out:
#        Country  year  Population continent  life_exp     gdp_cap  year+2
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314    1954
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030    1959

# %%
df['gdp'] = df['gdp_cap'] * df['Population']
df.head(2)
# Out:
#        Country  year  Population continent  life_exp     gdp_cap  year+2  \
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314    1954
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030    1959
#
#             gdp
# 0  6.567086e+09
# 1  7.585449e+09

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Country     1704 non-null   object
#  1   year        1704 non-null   int64
#  2   Population  1704 non-null   int64
#  3   continent   1704 non-null   object
#  4   life_exp    1704 non-null   float64
#  5   gdp_cap     1704 non-null   float64
#  6   year+2      1704 non-null   int64
#  7   gdp         1704 non-null   float64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 106.6+ KB

# %%
df["new_col"] = [i for i in range(1704)]

# %%
df
# Out:
#           Country  year  Population continent  life_exp     gdp_cap  year+2  \
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314    1954
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030    1959
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710    1964
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138    1969
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106    1974
# ...           ...   ...         ...       ...       ...         ...     ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306    1989
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786    1994
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960    1999
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623    2004
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298    2009
#
#                gdp  new_col
# ...

# %% [markdown]
# Length of new column cannot be greater than the array or data exisitng.

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1704, step=1)

# %%
df.index.values
# Out:
# array([   0,    1,    2, ..., 1701, 1702, 1703])

# %%
df.index = list(range(2, df.shape[0] +2))

# %%
df.index.values
# Out:
# array([   2,    3,    4, ..., 1703, 1704, 1705])

# %%
df.index[2]
# Out:
# 4

# %%
df.loc[2]
# Out:
# Country             Afghanistan
# year                       1952
# Population              8425333
# continent                  Asia
# life_exp                 28.801
# gdp_cap              779.445314
# year+2                     1954
# gdp           6567086329.952229
# new_col                       0
# Name: 2, dtype: object

# %%
import pandas as pd

# Creating a DataFrame
data = {
    'A': [10, 20, 30, 40],
    'B': [50, 60, 70, 80]
}
df = pd.DataFrame(data)

# Implicit indexing using iloc
print(df.iloc[0])      # First row
print(df.iloc[1:3])    # Rows 1 to 2 (0-based)
print(df.iloc[:, 0])
# Out:
# A    10
# B    50
# Name: 0, dtype: int64
#     A   B
# 1  20  60
# 2  30  70
# 0    10
# 1    20
# 2    30
# 3    40
# Name: A, dtype: int64

# %%
df.iloc[1:3]
# Out:
#        Country  year  Population continent  life_exp    gdp_cap
# 1  Afghanistan  1957     9240934      Asia    30.332  820.85303
# 2  Afghanistan  1962    10267083      Asia    31.997  853.10071

# %%
df.loc[2:4] # this is defining explicit indexing so it will be inclusive of 4
# Out:
#        Country  year  Population continent  life_exp     gdp_cap
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.iloc[-1]
# Out:
# Country         Zimbabwe
# year                2007
# Population      12311143
# continent         Africa
# life_exp          43.487
# gdp_cap       469.709298
# Name: 1703, dtype: object

# %%
temp = df.set_index("Country")

# %%
temp
# Out:
#              year  Population continent  life_exp     gdp_cap
# Country
# Afghanistan  1952     8425333      Asia    28.801  779.445314
# Afghanistan  1957     9240934      Asia    30.332  820.853030
# Afghanistan  1962    10267083      Asia    31.997  853.100710
# Afghanistan  1967    11537966      Asia    34.020  836.197138
# Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...         ...       ...       ...         ...
# Zimbabwe     1987     9216418    Africa    62.351  706.157306
# Zimbabwe     1992    10704340    Africa    60.377  693.420786
# Zimbabwe     1997    11404948    Africa    46.809  792.449960
# Zimbabwe     2002    11926563    Africa    39.989  672.038623
# Zimbabwe     2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
temp.loc["Afghanistan"]  #this optimizin the recall of the query to find by one particular column
# Out:
#              year  Population continent  life_exp     gdp_cap
# Country
# Afghanistan  1952     8425333      Asia    28.801  779.445314
# Afghanistan  1957     9240934      Asia    30.332  820.853030
# Afghanistan  1962    10267083      Asia    31.997  853.100710
# Afghanistan  1967    11537966      Asia    34.020  836.197138
# Afghanistan  1972    13079460      Asia    36.088  739.981106
# Afghanistan  1977    14880372      Asia    38.438  786.113360
# Afghanistan  1982    12881816      Asia    39.854  978.011439
# Afghanistan  1987    13867957      Asia    40.822  852.395945
# Afghanistan  1992    16317921      Asia    41.674  649.341395
# Afghanistan  1997    22227415      Asia    41.763  635.341351
# Afghanistan  2002    25268405      Asia    42.129  726.734055
# Afghanistan  2007    31889923      Asia    43.828  974.580338

# %%
df.reset_index() # this will store the explicit index as a column and implicit index will be set as index, making explicit and implicit indexex same.
# Out:
#       index      Country  year  Population continent  life_exp     gdp_cap
# 0         0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1         1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2         2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3         3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4         4  Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...     ...          ...   ...         ...       ...       ...         ...
# 1699   1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700   1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701   1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702   1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703   1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 7 columns]

# %%
df.reset_index(drop = True , inplace = True)

# %%
new_row = {'Country': 'India', 'year': 2000, 'life_exp': 37.08, 'population': 3500000, 'gdp_cap': 900.23}

# %%
new_row_series = pd.Series(new_row)
df = pd.concat([df,pd.DataFrame([new_row_series])], ignore_index = True)

# %%
print(df)
# Out:
#           Country  year  Population continent  life_exp     gdp_cap  \
# 0     Afghanistan  1952   8425333.0      Asia    28.801  779.445314
# 1     Afghanistan  1957   9240934.0      Asia    30.332  820.853030
# 2     Afghanistan  1962  10267083.0      Asia    31.997  853.100710
# 3     Afghanistan  1967  11537966.0      Asia    34.020  836.197138
# 4     Afghanistan  1972  13079460.0      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1992  10704340.0    Africa    60.377  693.420786
# 1701     Zimbabwe  1997  11404948.0    Africa    46.809  792.449960
# 1702     Zimbabwe  2002  11926563.0    Africa    39.989  672.038623
# 1703     Zimbabwe  2007  12311143.0    Africa    43.487  469.709298
# 1704        India  2000         NaN       NaN    37.080  900.230000
#
#       population
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 1700         NaN
# ...

# %%
len(df.index)
# Out:
# 1705

# %%
df.loc[1804] = ["India",2000,32242424,"Asia",43.34, 34345.344]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-6e9058ac5651> in <cell line: 1>()
# ----> 1 df.loc[1804] = ["India",2000,32242424,"Asia",43.34, 34345.344]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     909
#     910         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 911         iloc._setitem_with_indexer(indexer, value, self.name)
#     912
#     913     def _validate_key(self, key, axis: AxisInt):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1930
#    1931             if missing:
# -> 1932                 self._setitem_with_indexer_missing(indexer, value)
#    1933                 return
#    1934
#
# ...

# %%
df = pd.DataFrame([[1, 2], ["Ram", "Shyam"], ["IT", "Ops"]], columns = ["emp_id", "name", "dept"])
df
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in _finalize_columns_and_data(content, columns, dtype)
#     938     try:
# --> 939         columns = _validate_or_indexify_columns(contents, columns)
#     940     except AssertionError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in _validate_or_indexify_columns(content, columns)
#     985             # caller's responsibility to check for this...
# --> 986             raise AssertionError(
#     987                 f"{len(columns)} columns passed, passed data had "
#
# AssertionError: 3 columns passed, passed data had 2 columns
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# ...

# %%
df = pd.DataFrame([[1, "Ram", "IT"], [2, "Shyam", "Ops"]], columns = ["emp_id", "name", "dept"])

# %%
df = pd.DataFrame([1, "Ram", "IT"], columns = ["emp_id", "name", "dept"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-c40ce568923f> in <cell line: 1>()
# ----> 1 df = pd.DataFrame([1, "Ram", "IT"], columns = ["emp_id", "name", "dept"])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     865                     )
#     866                 else:
# --> 867                     mgr = ndarray_to_mgr(
#     868                         data,
#     869                         index,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     334     )
#     335
# --> 336     _check_values_indices_shape_match(values, index, columns)
#     337
#     338     if typ == "array":
#
# ...

# %%
df = pd.DataFrame({'emp_id':[1, 2], 'name': ['Ram', 'Shyam'], 'dept':['IT', 'Ops']})

# %%
You're working on collecting the text data for a Natural Language Processing(NLP) project. You come up with the idea of storing the unique words (case-sensitive) with their frequency in a Pandas Series object.

You are given the raw data in form of a string, Write a function which can take a string as an input and return the unique words and the corresponding frequency in form of a Pandas Series object.

The indices of the series should be the unique words and the values should be the frequency of those unique words.

Note that:

String contains no special character.
Always a Non-empty string.
Case sensitive i.e. He and he should be treated as two different word tokens.
Series returned is expected to be sorted by sort_index()for sorting all the words.
Input Format
Number of testcases
String with space separated words. (basically a sentence)
Output Format
space separated words in first line.
space separated values in the second line.
Sample Input
1
How much wood would a woodchuck chuck if a woodchuck could chuck wood
Sample Output
# Out:
#   File "<ipython-input-54-d4f2da99d267>", line 1
#     You're working on collecting the text data for a Natural Language Processing(NLP) project. You come up with the idea of storing the unique words (case-sensitive) with their frequency in a Pandas Series object.
#        ^
# SyntaxError: unterminated string literal (detected at line 1)
